# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio

# %%
{ "The Bodyguard":"1992", "Saturday Night Fever":"1977"}
# Out:
# {'The Bodyguard': '1992', 'Saturday Night Fever': '1977'}

# %% [markdown]
# <b>YAO-Tsung Chiang</b>
#     <br>CEO, Non-profit organization

# %% [markdown]
# <I>You can start your first sentence with "I am interested in data science because data analysis technology can provide the local government to build a people-oriented city.</I>

# %% [markdown]
# <h3> The following code tests the Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# <hr><b><UL>
# <LI>one
# <LI>two
# <LI>three
# <LI>one
# <LI>two
# <LI>three
#
#
#
#
# <br><br><a>www.ibm.com
